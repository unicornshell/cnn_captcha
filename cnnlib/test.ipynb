# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19936/4019025996.py in <module>
#       3 image=ImageCaptcha(fonts=['/path/A.ttf','/path/B.ttf'])
#       4
# ----> 5 data=image.generate('1234')
#       6 image.write('1234','out.png')
#       7
#
# D:\anaconda\envs\cnn_test\lib\site-packages\captcha\image.py in generate(self, chars, format)
#      43         :param format: image file format
#      44         """
# ---> 45         im = self.generate_image(chars)
#      46         out = BytesIO()
#      47         im.save(out, format=format)
#
# D:\anaconda\envs\cnn_test\lib\site-packages\captcha\image.py in generate_image(self, chars)
#     226         background = random_color(238, 255)
#     227         color = random_color(10, 200, random.randint(220, 255))
# --> 228         im = self.create_captcha_image(chars, color, background)
# ...
